# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import datetime as dt
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 623

# %% [markdown]
# ---

# %% [markdown]
# ## Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
BASE_URL = f"https://api.openweathermap.org/data/2.5/weather?units=imperial&appid={weather_api_key}"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# # Create counters
record_count = 1
set_count = 1

# # Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
# Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0
    # Create endpoint URL with each city
    city_url = f"{BASE_URL}&q={city.replace(' ', '+')}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        
        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = dt.datetime.utcfromtimestamp(city_weather['dt']).strftime('%Y-%m-%d %H:%M:%S')
        

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except KeyError:
        print(f"City {city} not found. Skipping...")
        pass
        
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | cape town
# Processing Record 2 of Set 1 | barrow
# Processing Record 3 of Set 1 | karratha
# Processing Record 4 of Set 1 | payakumbuh
# Processing Record 5 of Set 1 | mataura
# Processing Record 6 of Set 1 | victoria
# Processing Record 7 of Set 1 | butaritari
# Processing Record 8 of Set 1 | bluff
# Processing Record 9 of Set 1 | atuona
# Processing Record 10 of Set 1 | hilo
# Processing Record 11 of Set 1 | sumbawa
# City sumbawa not found. Skipping...
# Processing Record 12 of Set 1 | tsumeb
# Processing Record 13 of Set 1 | ukiah
# Processing Record 14 of Set 1 | saint-philippe
# Processing Record 15 of Set 1 | mezen
# Processing Record 16 of Set 1 | lyubech
# Processing Record 17 of Set 1 | korla
# Processing Record 18 of Set 1 | qasigiannguit
# Processing Record 19 of Set 1 | ranong
# Processing Record 20 of Set 1 | banjar
# Processing Record 21 of Set 1 | kapaa
# Processing Record 22 of Set 1 | haibowan
# City haibowan not found. Skipping...
# Processing Record 23 of Set 1 | amapa
# Processing Record 24 of Set 1 | tkvarcheli
# City tkvarcheli not found. Skipping...
# Processing Record 25 of Set 1 | sao paulo de olivenca
# Processing Record 26 of Set 1 | rikitea
# Processing Record 27 of Set 1 | kalmunai
# Processing Record 28 of Set 1 | albany
# Processing Record 29 of Set 1 | aktau
# Processing Record 30 of Set 1 | ushuaia
# Processing Record 31 of Set 1 | aguimes
# Processing Record 32 of Set 1 | kahului
# Processing Record 33 of Set 1 | weihai
# Processing Record 34 of Set 1 | ponta do sol
# Processing Record 35 of Set 1 | sur
# Processing Record 36 of Set 1 | kloulklubed
# Processing Record 37 of Set 1 | joao pinheiro
# Processing Record 38 of Set 1 | port alfred
# Processing Record 39 of Set 1 | hermanus
# Processing Record 40 of Set 1 | samarai
# Processing Record 41 of Set 1 | punta arenas
# Processing Record 42 of Set 1 | kaitangata
# Processing Record 43 of Set 1 | provideniya
# Processing Record 44 of Set 1 | namibe
# Processing Record 45 of Set 1 | pacific grove
# Processing Record 46 of Set 1 | stoyba
# City stoyba not found. Skipping...
# Processing Record 47 of Set 1 | salalah
# Processing Record 48 of Set 1 | longlac
# City longlac not found. Skipping...
# Processing Record 49 of Set 1 | haines junction
# Processing Record 50 of Set 1 | sao domingos
# Processing Record 0 of Set 2 | saskylakh
# Processing Record 1 of Set 2 | elko
# Processing Record 2 of Set 2 | tuktoyaktuk
# Processing Record 3 of Set 2 | faanui
# Processing Record 4 of Set 2 | bredasdorp
# Processing Record 5 of Set 2 | belushya guba
# City belushya guba not found. Skipping...
# Processing Record 6 of Set 2 | vaini
# Processing Record 7 of Set 2 | hokitika
# Processing Record 8 of Set 2 | georgetown
# Processing Record 9 of Set 2 | guerrero negro
# Processing Record 10 of Set 2 | leningradskiy
# Processing Record 11 of Set 2 | da nang
# Processing Record 12 of Set 2 | baherden
# Processing Record 13 of Set 2 | labuhan
# Processing Record 14 of Set 2 | port elizabeth
# Processing Record 15 of Set 2 | tahoua
# Processing Record 16 of Set 2 | buala
# Processing Record 17 of Set 2 | hobart
# Processing Record 18 of Set 2 | grand river south east
# City grand river south east not found. Skipping...
# Processing Record 19 of Set 2 | kamenka
# Processing Record 20 of Set 2 | severo-kurilsk
# Processing Record 21 of Set 2 | hasaki
# Processing Record 22 of Set 2 | sentyabrskiy
# City sentyabrskiy not found. Skipping...
# Processing Record 23 of Set 2 | marsa matruh
# Processing Record 24 of Set 2 | ustka
# Processing Record 25 of Set 2 | taolanaro
# City taolanaro not found. Skipping...
# Processing Record 26 of Set 2 | illoqqortoormiut
# City illoqqortoormiut not found. Skipping...
# Processing Record 27 of Set 2 | dikson
# Processing Record 28 of Set 2 | norman wells
# Processing Record 29 of Set 2 | vaitupu
# City vaitupu not found. Skipping...
# Processing Record 30 of Set 2 | busselton
# Processing Record 31 of Set 2 | chuy
# Processing Record 32 of Set 2 | cayenne
# Processing Record 33 of Set 2 | torbay
# Processing Record 34 of Set 2 | clyde river
# Processing Record 35 of Set 2 | sao filipe
# Processing Record 36 of Set 2 | khatanga
# Processing Record 37 of Set 2 | namtsy
# Processing Record 38 of Set 2 | flinders
# Processing Record 39 of Set 2 | yellowknife
# Processing Record 40 of Set 2 
# Processing Record 14 of Set 4 | samsun
# Processing Record 15 of Set 4 | kidal
# Processing Record 16 of Set 4 | kavieng
# Processing Record 17 of Set 4 | tura
# Processing Record 18 of Set 4 | houma
# Processing Record 19 of Set 4 | wulanhaote
# City wulanhaote not found. Skipping...
# Processing Record 20 of Set 4 | kysyl-syr
# Processing Record 21 of Set 4 | samusu
# City samusu not found. Skipping...
# Processing Record 22 of Set 4 | havelock
# Processing Record 23 of Set 4 | sorvag
# City sorvag not found. Skipping...
# Processing Record 24 of Set 4 | la peca
# Processing Record 25 of Set 4 | usinsk
# Processing Record 26 of Set 4 | huarmey
# Processing Record 27 of Set 4 | nyurba
# Processing Record 28 of Set 4 | boca do acre
# Processing Record 29 of Set 4 | meulaboh
# Processing Record 30 of Set 4 | mandalgovi
# Processing Record 31 of Set 4 | katangli
# Processing Record 32 of Set 4 | eregli
# Processing Record 33 of Set 4 | dauriya
# Processing Record 34 of Set 4 | pisco
# Processing Record 35 of Set 4 | dibai
# Processing Record 36 of Set 4 | barawe
# City barawe not found. Skipping...
# Processing Record 37 of Set 4 | dicabisagan
# Processing Record 38 of Set 4 | ghanzi
# Processing Record 39 of Set 4 | bethel
# Processing Record 40 of Set 4 | jamame
# Processing Record 41 of Set 4 | hobyo
# Processing Record 42 of Set 4 | tiksi
# Processing Record 43 of Set 4 | willowmore
# Processing Record 44 of Set 4 | ulaangom
# Processing Record 45 of Set 4 | mahebourg
# Processing Record 46 of Set 4 | west bay
# Processing Record 47 of Set 4 | mar del plata
# Processing Record 48 of Set 4 | tumannyy
# City tumannyy not found. Skipping...
# Processing Record 49 of Set 4 | port macquarie
# Processing Record 0 of Set 5 | orgun
# City orgun not found. Skipping...
# Processing Record 1 of Set 5 | pevek
# Processing Record 2 of Set 5 | lagoa
# Processing Record 3 of Set 5 | saleaula
# City saleaula not found. Skipping...
# Processing Record 4 of Set 5 | sobolevo
# Processing Record 5 of Set 5 | san cristobal
# Processing Record 6 of Set 5 | kyabe
# Processing Record 7 of Set 5 | barbar
# City barbar not found. Skipping...
# Processing Record 8 of Set 5 | danjiangkou
# Processing Record 9 of Set 5 | juan lacaze
# Processing Record 10 of Set 5 | sapouy
# Processing Record 11 of Set 5 | tucuman
# Processing Record 12 of Set 5 | amderma
# City amderma not found. Skipping...
# Processing Record 13 of Set 5 | satitoa
# City satitoa not found. Skipping...
# Processing Record 14 of Set 5 | laguna
# Processing Record 15 of Set 5 | lompoc
# Processing Record 16 of Set 5 | havoysund
# Processing Record 17 of Set 5 | yar-sale
# Processing Record 18 of Set 5 | ryazhsk
# Processing Record 19 of Set 5 | dubbo
# Processing Record 20 of Set 5 | hualmay
# Processing Record 21 of Set 5 | taltal
# Processing Record 22 of Set 5 | bela
# Processing Record 23 of Set 5 | kommunar
# Processing Record 24 of Set 5 | ostrovnoy
# Processing Record 25 of Set 5 | brainerd
# Processing Record 26 of Set 5 | miranorte
# City miranorte not found. Skipping...
# Processing Record 27 of Set 5 | cafarnaum
# Processing Record 28 of Set 5 | alamosa
# Processing Record 29 of Set 5 | kolda
# Processing Record 30 of Set 5 | east london
# Processing Record 31 of Set 5 | yashkul
# Processing Record 32 of Set 5 | kabwe
# Processing Record 33 of Set 5 | bilibino
# Processing Record 34 of Set 5 | itarema
# Processing Record 35 of Set 5 | saldanha
# Processing Record 36 of Set 5 | galion
# Processing Record 37 of Set 5 | oranjestad
# Processing Record 38 of Set 5 | salamiyah
# Processing Record 39 of Set 5 | attawapiskat
# City attawapiskat not found. Skipping...
# Processing Record 40 of Set 5 | moron
# Processing Record 41 of Set 5 | ust-tsilma
# Processing Record 42 of Set 5 | narasannapeta
# Processing Record 43 of Set 5 | northam
# Processing Record 44 of Set 5 | iqaluit
# Processing Record 45 of Set 5 | abu samrah
# Processing Record 46 of Set 5 | atasu
# Processing Record 47 of Set 5 | the valley
# Processing Record 48 of Set 5 | honavar
# Processing Record 49 of Set 5 | mys shmidta
# City mys shmidta not found. Skipping...
# Processing Record 0 of Set 6 | isiro
# Processing Record 1 of Set 6 | hvammstangi
# City hvammstangi not found. Skipping...
# Processing Record 2 of Set 6 | berlevag
# Processing Record 3 of Set 6 | chinhoyi
# Processing Record 4 of Set 6 | klaksvik
# Processing Record 5 of Set 6 | natchitoches
# Processing Record 6 of Set 6 | dingle
# Processing Record 7 of Set 6 | flic en flac
# Processing Record 8 of Set 6 | nuoro
# Processing Record 9 of Set 6 | saint-augustin
# Processing Record 10 of Set 6 | meiganga
# Processing Record 11 of Set 6 | tuatapere
# Processing Record 12 of Set 6 | corpus christi
# Processing Record 13 of Set 6 | yaan
# Processing Record 14 of Set 6 | beloha
# Processing Record 15 of Set 6 | bismarck
# Processing Record 16 of Set 6 | addanki
# Processing Record 17 of Set 6 | port moresby
# Processing Record 18 of Set 6 | camacha
# Processing Record 19 of Set 6 | panguna
# Processing Record 20 of Set 6 | lazaro cardenas
# Processing Record 21 of Set 6 | huallanca
# Processing Record 22 of Set 6 | coahuayana
# Processing Record 23 of Set 6 | buriti bravo
# Processing Record 24 of Set 6 | gamba
# Processing Record 25 of Set 6 | san juan
# Processing Record 26 of Set 6 | bonavista
# Processing Record 27 of Set 6 | verkhnevilyuysk
# Processing Record 28 of Set 6 | fairbanks
# Processing Record 29 of Set 6 | hamilton
# Processing Record 30 of Set 6 | vardo
# Processing Record 31 of Set 6 | castro
# Processing Record 32 of Set 6 | asau
# Processing Record 33 of Set 6 | dillon
# Processing Record 34 of Set 6 | gazli
# Processing Record 35 of Set 6 | mombetsu
# Processing Record 36 of Set 6 | aleksandrovsk-sakhalinskiy
# Processing Record 37 of Set 6 | thompson
# Processing Record 38 of Set 6 | abu kamal
# Processing Record 39 of Set 6 | tabuk
# Processing Record 40 of Set 6 | kangaatsiaq
# Processing Record 41 of Set 6 | sept-iles
# Processing Record 42 of Set 6 | suntar
# Processing Record 43 of Set 6 | beyneu
# Processing Record 44 of Set 6 | masvingo
# Processing Record 45 of Set 6 | vila velha
# City louisbourg not found. Skipping...
# Processing Record 25 of Set 9 | oil city
# Processing Record 26 of Set 9 | nouadhibou
# Processing Record 27 of Set 9 | greenville
# Processing Record 28 of Set 9 | erenhot
# Processing Record 29 of Set 9 | riyadh
# Processing Record 30 of Set 9 | ovalle
# Processing Record 31 of Set 9 | sattahip
# Processing Record 32 of Set 9 | beringovskiy
# Processing Record 33 of Set 9 | sao miguel do araguaia
# Processing Record 34 of Set 9 | azrow
# City azrow not found. Skipping...
# Processing Record 35 of Set 9 | wyndham
# Processing Record 36 of Set 9 | broken hill
# Processing Record 37 of Set 9 | mutsamudu
# City mutsamudu not found. Skipping...
# Processing Record 38 of Set 9 | ternate
# Processing Record 39 of Set 9 | pacifica
# Processing Record 40 of Set 9 | barkhan
# Processing Record 41 of Set 9 | baisha
# Processing Record 42 of Set 9 | margate
# Processing Record 43 of Set 9 | visby
# Processing Record 44 of Set 9 | avera
# Processing Record 45 of Set 9 | vilyuysk
# Processing Record 46 of Set 9 | warrington
# Processing Record 47 of Set 9 | cap-chat
# Processing Record 48 of Set 9 | malwan
# City malwan not found. Skipping...
# Processing Record 49 of Set 9 | payo
# Processing Record 0 of Set 10 | lukulu
# Processing Record 1 of Set 10 | vao
# Processing Record 2 of Set 10 | montepuez
# Processing Record 3 of Set 10 | luangwa
# Processing Record 4 of Set 10 | carora
# Processing Record 5 of Set 10 | seidu
# Processing Record 6 of Set 10 | puerto princesa
# Processing Record 7 of Set 10 | tomatlan
# Processing Record 8 of Set 10 | rozkishne
# Processing Record 9 of Set 10 | naryan-mar
# Processing Record 10 of Set 10 | ust-omchug
# Processing Record 11 of Set 10 | prince rupert
# Processing Record 12 of Set 10 | nuuk
# Processing Record 13 of Set 10 | yabelo
# Processing Record 14 of Set 10 | nizhneyansk
# City nizhneyansk not found. Skipping...
# Processing Record 15 of Set 10 | lashio
# Processing Record 16 of Set 10 | svetlogorsk
# Processing Record 17 of Set 10 | seydi
# Processing Record 18 of Set 10 | xixiang
# Processing Record 19 of Set 10 | bastia
# Processing Record 20 of Set 10 | bull savanna
# Processing Record 21 of Set 10 | tilichiki
# Processing Record 22 of Set 10 | domoni
# Processing Record 23 of Set 10 | teya
# Processing Record 24 of Set 10 | soyaux
# Processing Record 25 of Set 10 | hit
# Processing Record 26 of Set 10 | nara
# Processing Record 27 of Set 10 | grand gaube
# Processing Record 28 of Set 10 | uchiza
# Processing Record 29 of Set 10 | matay
# Processing Record 30 of Set 10 | qui nhon
# Processing Record 31 of Set 10 | turukhansk
# Processing Record 32 of Set 10 | llata
# Processing Record 33 of Set 10 | roald
# Processing Record 34 of Set 10 | mackenzie
# Processing Record 35 of Set 10 | tabou
# Processing Record 36 of Set 10 | makakilo city
# Processing Record 37 of Set 10 | kupino
# Processing Record 38 of Set 10 | zalantun
# Processing Record 39 of Set 10 | mecca
# Processing Record 40 of Set 10 | ponta delgada
# Processing Record 41 of Set 10 | cabo san lucas
# Processing Record 42 of Set 10 | ribeira grande
# Processing Record 43 of Set 10 | itamaraju
# Processing Record 44 of Set 10 | idlib
# Processing Record 45 of Set 10 | ewa beach
# Processing Record 46 of Set 10 | kholm-zhirkovskiy
# Processing Record 47 of Set 10 | sumenep
# Processing Record 48 of Set 10 | tecuala
# Processing Record 49 of Set 10 | killybegs
# Processing Record 0 of Set 11 | khorixas
# Processing Record 1 of Set 11 | mrirt
# City mrirt not found. Skipping...
# Processing Record 2 of Set 11 | matara
# Processing Record 3 of Set 11 | half moon bay
# Processing Record 4 of Set 11 | kinsale
# Processing Record 5 of Set 11 | portobelo
# Processing Record 6 of Set 11 | constitucion
# Processing Record 7 of Set 11 | isangel
# Processing Record 8 of Set 11 | tortosa
# Processing Record 9 of Set 11 | wanaka
# Processing Record 10 of Set 11 | sulina
# Processing Record 11 of Set 11 | bengkulu
# Processing Record 12 of Set 11 | flin flon
# Processing Record 13 of Set 11 | mount isa
# Processing Record 14 of Set 11 | clyde
# Processing Record 15 of Set 11 | afzalpur
# Processing Record 16 of Set 11 | broome
# Processing Record 17 of Set 11 | agirish
# Processing Record 18 of Set 11 | krasnyy chikoy
# Processing Record 19 of Set 11 | perth
# Processing Record 20 of Set 11 | shingu
# Processing Record 21 of Set 11 | ancud
# Processing Record 22 of Set 11 | tazovskiy
# Processing Record 23 of Set 11 | ust-nera
# Processing Record 24 of Set 11 | rorvik
# Processing Record 25 of Set 11 | jinchengjiang
# City jinchengjiang not found. Skipping...
# Processing Record 26 of Set 11 | bilma
# Processing Record 27 of Set 11 | diffa
# Processing Record 28 of Set 11 | pemangkat
# Processing Record 29 of Set 11 | faya
# Processing Record 30 of Set 11 | charters towers
# Processing Record 31 of Set 11 | grimari
# City grimari not found. Skipping...
# Processing Record 32 of Set 11 | porto novo
# Processing Record 33 of Set 11 | port lincoln
# Processing Record 34 of Set 11 | ust-barguzin
# Processing Record 35 of Set 11 | padang
# Processing Record 36 of Set 11 | manavalakurichi
# Processing Record 37 of Set 11 | waterloo
# Processing Record 38 of Set 11 | viedma
# Processing Record 39 of Set 11 | selenginsk
# Processing Record 40 of Set 11 | kumluca
# Processing Record 41 of Set 11 | sola
# Processing Record 42 of Set 11 | rabo de peixe
# Processing Record 43 of Set 11 | batemans bay
# Processing Record 44 of Set 11 | lincoln
# Processing Record 45 of Set 11 | haverhill
# Processing Record 46 of Set 11 | oyama
# Processing Record 47 of Set 11 | preobrazheniye
# Processing Record 48 of Set 11 | kamuli
# Processing Record 49 of Set 11 | goderich
# Processing Record 0 of Set 12 | pingshan
# Processing Record 1 of Set 12 | saint anthony
# Processing Record 2 of Set 12 | de aar
# Processing Record 3 of Set 12 | ambuclao
# Processing Record 4 of Set 12 | mpongwe
# Processing Record 5 of Set 12 | shevchenkove
# Processing Record 6 of Set 12 | oktyabrskoye
# Processing Record 7 of Set 12 | karaul
# City karaul not found. Skipping...
# Processing Record 8 of Set 12 | inderborskiy
# City inderborskiy not found. Skipping...
# Processing Record 9 of Set 12 | port-cartier
# Processing Record 10 of Set 12 | kinarut
# Processing Record 11 of Set 12 | zheleznodorozhnyy
# Processing Record 12 of Set 12 | vila do maio
# Processing Record 13 of Set 12 | parkersburg
# Processing Record 14 of Set 12 | mahanoro
# Processing Record 15 of Set 12 | kapuskasing
# Processing Record 16 of Set 12 | assiniboia
# Processing Record 17 of Set 12 | puerto madryn
# Processing Record 18 of Set 12 | pahrump
# Processing Record 19 of Set 12 | ossora
# Processing Record 20 of Set 12 | sao jose da coroa grande
# Processing Record 21 of Set 12 | karamea
# City karamea not found. Skipping...
# Processing Record 22 of Set 12 | puri
# Processing Record 23 of Set 12 | sembe
# Processing Record 24 of Set 12 | colesberg
# Processing Record 25 of Set 12 | jiaozuo
# Processing Record 26 of Set 12 | mayo
# Processing Record 27 of Set 12 | haukipudas
# Processing Record 28 of Set 12 | pierre
# Processing Record 29 of Set 12 | solnechnyy
# Processing Record 30 of Set 12 | cabedelo
# Processing Record 31 of Set 12 | tiarei
# Processing Record 32 of Set 12 | tame
# Processing Record 33 of Set 12 | kimbe
# Processing Record 34 of Set 12 | grimshaw
# Processing Record 35 of Set 12 | el badari
# City el badari not found. Skipping...
# Processing Record 36 of Set 12 | rio gallegos
# Processing Record 37 of Set 12 | kirakira
# Processing Record 38 of Set 12 | kashin
# Processing Record 39 of Set 12 | loa janan
# Processing Record 40 of Set 12 | namatanai
# Processing Record 41 of Set 12 | lodeynoye pole
# Processing Record 42 of Set 12 | waipawa
# Processing Record 43 of Set 12 | san policarpo
# Processing Record 44 of Set 12 | pucara
# Processing Record 45 of Set 12 | ust-maya
# Processing Record 46 of Set 12 | vidim
# Processing Record 47 of Set 12 | mastung
# Processing Record 48 of Set 12 | san-pedro
# Processing Record 49 of Set 12 | condado
# Processing Record 0 of Set 13 | rio grande
# Processing Record 1 of Set 13 | aksu
# Processing Record 2 of Set 13 | atar
# Processing Record 3 of Set 13 | dera bugti
# Processing Record 4 of Set 13 | ballina
# Processing Record 5 of Set 13 | alice springs
# Processing Record 6 of Set 13 | san mateo del mar
# Processing Record 7 of Set 13 | meyungs
# City meyungs not found. Skipping...
# Processing Record 8 of Set 13 | arawa
# Processing Record 9 of Set 13 | port hardy
# Processing Record 10 of Set 13 | tres arroyos
# Processing Record 11 of Set 13 | santa maria
# Processing Record 12 of Set 13 | komsomolskiy
# Processing Record 13 of Set 13 | maryborough
# Processing Record 14 of Set 13 | catalina
# Processing Record 15 of Set 13 | salinopolis
# Processing Record 16 of Set 13 | marihatag
# Processing Record 17 of Set 13 | palu
# Processing Record 18 of Set 13 | lata
# Processing Record 19 of Set 13 | betare oya
# Processing Record 20 of Set 13 | mufumbwe
# Processing Record 21 of Set 13 | palmer
# Processing Record 22 of Set 13 | gulu
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          567
# Lat           567
# Lng           567
# Max Temp      567
# Humidity      567
# Cloudiness    567
# Wind Speed    567
# Country       567
# Date          567
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   cape town -33.9258   18.4232     67.37        56           0       17.27
# 1      barrow  71.2906 -156.7887     -1.80        97         100        6.82
# 2    karratha -20.7377  116.8463     93.29        33           4        3.91
# 3  payakumbuh  -0.2202  100.6308     74.12        86         100        2.91
# 4     mataura -46.1927  168.8643     81.63        28           1        5.26
#
#   Country                 Date
# 0      ZA  2023-01-29 02:50:17
# 1      US  2023-01-29 02:53:38
# 2      AU  2023-01-29 02:53:39
# 3      ID  2023-01-29 02:53:39
# 4      NZ  2023-01-29 02:50:51

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0         cape town -33.9258   18.4232     67.37        56           0
# 1            barrow  71.2906 -156.7887     -1.80        97         100
# 2          karratha -20.7377  116.8463     93.29        33           4
# 3        payakumbuh  -0.2202  100.6308     74.12        86         100
# 4           mataura -46.1927  168.8643     81.63        28           1
#
#          Wind Speed Country                 Date
# City_ID
# 0             17.27      ZA  2023-01-29 02:50:17
# 1              6.82      US  2023-01-29 02:53:38
# 2              3.91      AU  2023-01-29 02:53:39
# 3              2.91      ID  2023-01-29 02:53:39
# 4              5.26      NZ  2023-01-29 02:50:51

# %%
# Create Northern and Southern Hemisphere DataFrames.
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %% [markdown]
# **Discussion about the linear relationship:** In the northern hemisphere, there appears to be a strong relationship between the latitude and temperature. However, in the southern hemisphere the relationship is significantly weaker.

# %%
# Build scatter plot for temp vs. latitude
# YOUR CODE HERE
x = northern_hemi_df["Lat"]
y = northern_hemi_df["Max Temp"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
R_R = rvalue**2
plt.scatter(x, y)
plt.plot(x, regress_values, "r-")
plt.annotate(line_eq, (0,-20), fontsize = 12, color="red")
plt.annotate(f"The r-value is {R_R}", (0,-30), fontsize = 12, color="black")
plt.suptitle("Northern Hemisphere: Temperature vs. Latitude", fontsize = 14)
plt.xlabel("Latitude", fontsize = 10)
plt.ylabel("Temperature (Farenheit)", fontsize = 10)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %%
# Build scatter plot for temp vs. latitude
# YOUR CODE HERE
x = southern_hemi_df["Lat"] 
y = southern_hemi_df["Max Temp"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
R_R = rvalue**2
plt.scatter(x, y)
plt.plot(x, regress_values, "r-")
plt.annotate(line_eq, (-50,50), fontsize = 12, color="red")
plt.annotate(f"The r-value is {R_R}", (-50,40), fontsize = 12, color="black")
plt.suptitle("Southern Hemisphere: Temperature vs. Latitude", fontsize = 14)
plt.xlabel("Latitude", fontsize = 10)
plt.ylabel("Temperature (Farenheit)", fontsize = 10)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %% [markdown]
# **Discussion about the linear relationship:** In both the northern and southern hemisphere, there is a very weak relationship between the latitude and the humidity levels.

# %%
# Build scatter plot for humidity vs. latitude
# YOUR CODE HERE
x = northern_hemi_df["Lat"]
y = northern_hemi_df["Humidity"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
R_R = rvalue**2
plt.scatter(x, y)
plt.plot(x, regress_values, "r-")
#Graph Properties
plt.suptitle("Northern Hemisphere: Humidity vs. Latitude", fontsize = 14)
plt.xlabel("Latitude", fontsize = 10)
plt.ylabel("Humidity", fontsize = 10)
#Annotations for LinReg and R value
plt.annotate(line_eq, (0,30), fontsize = 12, color="red")
plt.annotate(f"The r-value is {R_R}", (0,20), fontsize = 12, color="black")

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %%
# Build scatter plot for humidity vs. latitude
# YOUR CODE HERE
x = southern_hemi_df["Lat"]
y = southern_hemi_df["Humidity"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
R_R = rvalue**2
plt.scatter(x, y)
plt.plot(x, regress_values, "r-")
#Graph Properties
plt.suptitle("Southern Hemisphere: Humidity vs. Latitude", fontsize = 14)
plt.xlabel("Latitude", fontsize = 10)
plt.ylabel("Humidity", fontsize = 10)
#Annotations for LinReg and R value
plt.annotate(line_eq, (-55,30), fontsize = 12, color="red")
plt.annotate(f"The r-value is {R_R}", (-55,20), fontsize = 12, color="black")

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %% [markdown]
# **Discussion about the linear relationship:** In the northern hemisphere, there is essentially no relationship between cloudiness and the latitude. And in the southern hemisphere, the relationship is weak, but not as small for the northern hemisphere.

# %%
# Build scatter plot for Cloudiness vs. latitude
# YOUR CODE HERE
x = northern_hemi_df["Lat"] 
y = northern_hemi_df["Cloudiness"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
R_R = rvalue**2
plt.scatter(x, y)
plt.plot(x, regress_values, "r-")
#Graph Properties
plt.suptitle("Northern Hemisphere: Cloudiness vs. Latitude", fontsize = 14)
plt.xlabel("Latitude", fontsize = 10)
plt.ylabel("Cloudiness", fontsize = 10)
#Annotations for LinReg and R value
plt.annotate(line_eq, (0,30), fontsize = 12, color="red")
plt.annotate(f"The r-value is {R_R}", (0,20), fontsize = 12, color="black")

# Save the figure
plt.savefig("output_data/Fig5.png")

# Show plot
plt.show()

# %%
# Build scatter plot for Cloudiness vs. latitude
# YOUR CODE HERE
x = southern_hemi_df["Lat"] 
y = southern_hemi_df["Cloudiness"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
R_R = rvalue**2
plt.scatter(x, y)
plt.plot(x, regress_values, "r-")
#Graph Properties
plt.suptitle("Southern Hemisphere: Cloudiness vs. Latitude", fontsize = 14)
plt.xlabel("Latitude", fontsize = 10)
plt.ylabel("Cloudiness", fontsize = 10)
#Annotations for LinReg and R value
plt.annotate(line_eq, (-55,100), fontsize = 12, color="red")
plt.annotate(f"The r-value is {R_R}", (-55,85), fontsize = 12, color="black")

# Save the figure
plt.savefig("output_data/Fig6.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %% [markdown]
# **Discussion about the linear relationship:** There is virtually no relationship at all between latitude and wind speed.

# %%
# Build scatter plot for wind speed vs. latitude
# YOUR CODE HERE
x = northern_hemi_df["Lat"] 
y = northern_hemi_df["Wind Speed"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
R_R = rvalue**2
plt.scatter(x, y)
plt.plot(x, regress_values, "r-")
#Graph Properties
plt.suptitle("Northern Hemisphere: Wind Speed vs. Latitude", fontsize = 14)
plt.xlabel("Latitude", fontsize = 10)
plt.ylabel("Wind Speed", fontsize = 10)
#Annotations for LinReg and R value
plt.annotate(line_eq, (0,35), fontsize = 12, color="red")
plt.annotate(f"The r-value is {R_R}", (0,30), fontsize = 12, color="black")

# Save the figure
plt.savefig("output_data/Fig7.png")

# Show plot
plt.show()

# %%
# Build scatter plot for wind speed vs. latitude
# YOUR CODE HERE
x = southern_hemi_df["Lat"] 
y = southern_hemi_df["Wind Speed"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
R_R = rvalue**2
plt.scatter(x, y)
plt.plot(x, regress_values, "r-")
#Graph Properties
plt.suptitle("Southern Hemisphere: Wind Speed vs. Latitude", fontsize = 14)
plt.xlabel("Latitude", fontsize = 10)
plt.ylabel("Wind Speed", fontsize = 10)
#Annotations for LinReg and R value
plt.annotate(line_eq, (-55,25), fontsize = 12, color="red")
plt.annotate(f"The r-value is {R_R}", (-55,23), fontsize = 12, color="black")

# Save the figure
plt.savefig("output_data/Fig8.png")

# Show plot
plt.show()
